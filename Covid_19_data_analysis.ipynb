# %% [markdown]
# **Import the modules**

# %%
import io
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

print("Modules are imported...")
# Out:
# Modules are imported...

# %% [markdown]
# **Importing covid19 dataset**

# %%
covid_dataset_csv = pd.read_csv("/content/covid19_Confirmed_dataset.csv")
covid_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...     1939     2171
# 1                           NaN              Albania  ...      766      773
# 2                           NaN              Algeria  ...     3848     4006
# 3                           NaN              Andorra  ...      743      745
# 4                           NaN               Angola  ...       27       27
# 5                           NaN  Antigua and Barbuda  ...       24       24
# 6                           NaN            Argentina  ...     4285     4428
# 7                           NaN              Armenia  ...     1932     2066
# 8  Australian Capital Territory            Australia  ...      106      106
# 9               New South Wales            Australia  ...     3016     3025
#
# [10 rows x 104 columns]

# %% [markdown]
# Let's check the shape of dataframe

# %%
covid_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# **Delete the useless columns i.e. Long and Lat**

# %%
covid_dataset_csv.drop(['Lat', 'Long'], axis = 1, inplace = True)
covid_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...     1939     2171
# 1                           NaN              Albania  ...      766      773
# 2                           NaN              Algeria  ...     3848     4006
# 3                           NaN              Andorra  ...      743      745
# 4                           NaN               Angola  ...       27       27
# 5                           NaN  Antigua and Barbuda  ...       24       24
# 6                           NaN            Argentina  ...     4285     4428
# 7                           NaN              Armenia  ...     1932     2066
# 8  Australian Capital Territory            Australia  ...      106      106
# 9               New South Wales            Australia  ...     3016     3025
#
# [10 rows x 102 columns]

# %% [markdown]
# **Aggregating rows by the country**

# %%
covid_dataset_aggregated = covid_dataset_csv.groupby('Country/Region').sum()
covid_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                                  ...
# Afghanistan                0        0        0  ...     1828     1939     2171
# Albania                    0        0        0  ...      750      766      773
# Algeria                    0        0        0  ...     3649     3848     4006
# Andorra                    0        0        0  ...      743      743      745
# Angola                     0        0        0  ...       27       27       27
# Antigua and Barbuda        0        0        0  ...       24       24       24
# Argentina                  0        0        0  ...     4127     4285     4428
# Armenia                    0        0        0  ...     1867     1932     2066
# Australia                  0        0        0  ...     6744     6752     6766
# Austria                    0        0        0  ...    15357    15402    15452
#
# [10 rows x 100 columns]

# %%
covid_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# **Visualizing the data related to the country for example: INDIA**

# %%
  covid_dataset_aggregated.loc['India'].plot()
  covid_dataset_aggregated.loc['China'].plot()
  covid_dataset_aggregated.loc['Italy'].plot()
  covid_dataset_aggregated.loc['Spain'].plot()
  plt.legend()

# %% [markdown]
# **Calculating good measures**
#
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
covid_dataset_aggregated.loc['India'].plot()

# %%
covid_dataset_aggregated.loc['India'].diff().plot()

# %%
covid_dataset_aggregated.loc['India'].diff().max()
# Out:
# 1893.0

# %%
covid_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
covid_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
covid_dataset_aggregated.loc['Spain'].diff().max()
# Out:
# 9630.0

# %% [markdown]
# **Finding maximum infection rate for all the countries**

# %%
countries = list(covid_dataset_aggregated.index)
max_infection_rates = []
for country in countries:
    max_infection_rates.append(covid_dataset_aggregated.loc[country].diff().max())
covid_dataset_aggregated['max_infection_rates'] = max_infection_rates
covid_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  ...  4/30/20  max_infection_rates
# Country/Region                    ...
# Afghanistan           0        0  ...     2171                232.0
# Albania               0        0  ...      773                 34.0
# Algeria               0        0  ...     4006                199.0
# Andorra               0        0  ...      745                 43.0
# Angola                0        0  ...       27                  5.0
#
# [5 rows x 101 columns]

# %% [markdown]
# **Create new dataframe only with needed columns**

# %%
covid_data = pd.DataFrame(covid_dataset_aggregated['max_infection_rates'])
covid_data.head()
# Out:
#                 max_infection_rates
# Country/Region
# Afghanistan                   232.0
# Albania                        34.0
# Algeria                       199.0
# Andorra                        43.0
# Angola                          5.0

# %% [markdown]
# 1. Importing the WorldHappinessReport.csv dataset
# 2. selecting needed columns for our analysis
# 3. join the datasets
# 4. calculate the correlations as the result of our analysis **bold text**

# %%
world_happiness_report = pd.read_csv("/content/worldwide_happiness_report.csv")
world_happiness_report.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
world_happiness_report.shape
# Out:
# (156, 9)

# %%
columns_to_drop = ['Overall rank', 'Score', 'Generosity', 'Perceptions of corruption']
world_happiness_report.drop(columns_to_drop, axis = 1, inplace = True)

# %%
world_happiness_report.head()
# Out:
#   Country or region  ...  Freedom to make life choices
# 0           Finland  ...                         0.596
# 1           Denmark  ...                         0.592
# 2            Norway  ...                         0.603
# 3           Iceland  ...                         0.591
# 4       Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %%
world_happiness_report.set_index(['Country or region'], inplace = True)
world_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
covid_data.head()
# Out:
#                 max_infection_rates
# Country/Region
# Afghanistan                   232.0
# Albania                        34.0
# Algeria                       199.0
# Andorra                        43.0
# Angola                          5.0

# %% [markdown]
# **Joining two dataset**

# %%
data = world_happiness_report.join(covid_data).copy()
data.head()
# Out:
#                    GDP per capita  ...  max_infection_rates
# Country or region                  ...
# Finland                     1.340  ...                267.0
# Denmark                     1.383  ...                391.0
# Norway                      1.488  ...                386.0
# Iceland                     1.380  ...                 99.0
# Netherlands                 1.396  ...               1346.0
#
# [5 rows x 5 columns]

# %% [markdown]
# **Correlation Matrix**

# %%
data.corr()
# Out:
#                               GDP per capita  ...  max_infection_rates
# GDP per capita                      1.000000  ...             0.250118
# Social support                      0.754906  ...             0.191958
# Healthy life expectancy             0.835462  ...             0.289263
# Freedom to make life choices        0.379079  ...             0.078196
# max_infection_rates                 0.250118  ...             1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# **Visualization of the results**

# %%
data.head()
# Out:
#                    GDP per capita  ...  max_infection_rates
# Country or region                  ...
# Finland                     1.340  ...                267.0
# Denmark                     1.383  ...                391.0
# Norway                      1.488  ...                386.0
# Iceland                     1.380  ...                 99.0
# Netherlands                 1.396  ...               1346.0
#
# [5 rows x 5 columns]

# %% [markdown]
# **Plotting GDP vs Max infection rate**

# %%
x = data['GDP per capita']
y = data['max_infection_rates']
sns.scatterplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Plotting Social Support vs max infection rate**

# %%
x = data['Social support']
y = data['max_infection_rates']
sns.scatterplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Plotting Healthy Life Expectancy vs Max Infection Rates**

# %%
x = data['Healthy life expectancy']
y = data['max_infection_rates']
sns.scatterplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Plotting Freedom to make Life Choices vs Max Infection Rates**

# %%
x = data['Freedom to make life choices']
y = data['max_infection_rates']
sns.scatterplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x, np.log(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
